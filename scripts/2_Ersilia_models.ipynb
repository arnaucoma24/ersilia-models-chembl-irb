# %%
import pandas as pd

# %%
airtable = pd.read_csv("../data/ErsiliaModelsPublic.csv")
airtable = airtable[(airtable['Status'] == 'Ready') & (airtable['Task'] == 'Representation')].reset_index(drop=True)  # output score/value ; output dimension
cols = ['Identifier', 'Slug', 'Title', 'Subtask', 'Output Dimension', 'Computational Performance 2', 'Computational Performance 4', 'Computational Performance 5']
airtable = airtable[cols]

# %%
airtable.sort_values('Computational Performance 4')  # + eos42ez
# Out:
#    Identifier                                 Slug  \
# 30    eos2rd8              molt5-smiles-to-caption
# 28    eos4se9                         smiles2iupac
# 38    eos7asg                                padel
# 43    eos5axz                        morgan-counts
# 21    eos2gw4           ersilia-compound-embedding
# 0     eos11sr                                emfps
# 32    eos2mrz                           deepsmiles
# 19    eos1mxi                            smiles-pe
# 33    eos6pbf                              selfies
# 14    eos5guo                     erg-fingerprints
# 42    eos8h6g                               avalon
# 15    eos4wt0                    morgan-binary-fps
# 41    eos7jio                    rdkit-fingerprint
# 29    eos24ci                              drugtax
# 7     eos4ex3                 mole-representations
# 12    eos4djh            datamol-basic-descriptors
# 40    eos8a4x                    rdkit-descriptors
# 1     eos9o72                            chemeleon
# 34    eos6tg8          natural-product-fingerprint
# 45    eos1vms          chembl-multitask-descriptor
# 25    eos7qga             datamol-smiles2canonical
# 23    eos3zur                       molfeat-estate
# 37    eos2lm8                   smiles-transformer
# 36    eos78ao                              mordred
# 26    eos4avb                 image-mol-embeddings
# 24    eos6aun                      rxn-fingerprint
# 13    eos39co                unimol-representation
# 18    eos9zw0                            molpmofit
# 46    eos4u6p                      cc-signaturizer
# 11    eos9gg2  chemical-space-projections-drugbank
# 20    eos59rr              bidd-molmap-fingerprint
# 8     eos8aa5                      kgpgt-embedding
# 16    eos1ut3                       molfeat-usrcat
# 17    eos4x30                           pmapper-3d
# 2     eos2sbn                 cc-signaturizer-3d-a
# 5     eos77jk                 cc-signaturizer-3d-d
# 3     eos2mxh                 cc-signaturizer-3d-b
# 6     eos4jcv                 cc-signaturizer-3d-e
# 44    eos3ae6                    whales-descriptor
# 4     eos2h1r                 cc-signaturizer-3d-c
# 22    eos3cf4                      molfeat-chemgpt
# 31    eos6m4j                     bidd-molmap-desc
# 10    eos2db3   chemical-space-projections-chemdiv
# 27    eos93h2                       image-mol-gpcr
# 9     eos8ub5   chemical-space-projections-coconut
# 35    eos2thm                              molbert
# 39    eos7w6n                     grover-embedding
#
#                                                 Title        Subtask  \
# 30  MolT5-Translation between Molecules and Natura...  Featurization
# 28             STOUT: SMILES to IUPAC name translator  Featurization
# 38                   PADEL small molecule descriptors  Featurization
# 43                         Morgan counts fingerprints  Featurization
# 21                        Ersilia Compound Embeddings  Featurization
# 0                        Embedded Morgan Fingerprints  Featurization
# 32  DeepSMILES, an alternate SMILES representation...  Featurization
# 19  SmilesPE: tokenizer algorithm for SMILES, Deep...  Featurization
# 33                  SELF-referencIng Embedded Strings  Featurization
# 14                                 ErG 2D Descriptors  Featurization
# 42                                 Avalon fingerprint  Featurization
# 15  Morgan fingerprints in binary form (radius 3, ...  Featurization
# 41                             Path-based fingerprint  Featurization
# 29                             DrugTax: Drug taxonomy  Featurization
# 7   MolE molecular representation through redundan...  Featurization
# 12           Basic molecular descriptors from Datamol  Featurization
# 40   Physicochemical descriptors available from RDKIT  Featurization
# 1                                CheMeleon embeddings  Featurization
# 34                        Natural product fingerprint  Featurization
# 45       Multi-target prediction based on ChEMBL data  Featurization
# 25  Converter of SMILES in Canonical, Selfie, Inch...  Featurization
# 23                       Estate Molecular Descriptors  Featurization
# 37                      SMILES transformer descriptor  Featurization
# 36                       Mordred chemical descriptors  Featurization
# 26                  Molecular representation learning  Featurization
# 24             RXNFP - chemical reaction fingerprints  Featurization
# 13                   Uni-Mol molecular representation  Featurization
# 18  Molecular Prediction Model Fine-Tuning (MolPMo...  Featurization
# 46                      Chemical Checker signaturizer  Featurization
# 11     Chemical space 2D projections against DrugBank     Projection
# 20  Molecular fingerprint maps based on broadly le...  Featurization
# 8      Knowledge-guided pre-trained graph transformer  Featurization
# 16    USR descriptors with pharmacophoric constraints  Featurization
# 17                        3D pharmacophore descriptor  Featurization
# 2               Chemical Checker Signaturizer 3D A1-5  Featurization
# 5               Chemical Checker Signaturizer 3D D1-5  Featurization
# 3               Chemical Checker Signaturizer 3D B1-5  Featurization
# 6               Chemical Checker Signaturizer 3D E1-5  Featurization
# 44  Holistic molecular descriptors for scaffold ho...  Featurization
# 4               Chemical Checker Signaturizer 3D C1-5  Featurization
# 22                                        ChemGPT-4.7  Featurization
# 31  Molecular maps based on broadly learned knowle...  Featurization
# 10      Chemical space 2D projections against ChemDiv     Projection
# 27                                      imagemol-gpcr  Featurization
# 9                         Projections against Coconut     Projection
# 35              MolBERT chemical language transformer  Featurization
# 39                      Large-scale graph transformer  Featurization
#
#     Output Dimension  Computational Performance 2  \
# 30               1.0                        836.7
# 28               1.0                        732.4
# 38            1875.0                         56.7
# 43            2048.0                         16.6
# 21            1024.0                         17.0
# 0             1024.0                         18.3
# 32               1.0                         18.4
# 19              50.0                         18.6
# 33               1.0                         18.7
# 14             315.0                         19.2
# 42            1024.0                         19.1
# 15            2048.0                         19.2
# 41            2048.0                         19.1
# 29             163.0                         19.7
# 7             1000.0                         21.6
# 12              22.0                         20.6
# 40             200.0                         19.5
# 1             2048.0                         21.4
# 34              65.0                         22.6
# 45               1.0                         20.8
# 25               3.0                         22.3
# 23              79.0                         26.8
# 37            1024.0                         24.2
# 36            1458.0                         19.6
# 26             512.0                         23.9
# 24             256.0                         27.9
# 13             512.0                         24.3
# 18             400.0                         31.1
# 46            3200.0                         41.4
# 11               8.0                         62.8
# 20            1332.0                         58.4
# 8             2304.0                         33.9
# 16              60.0                         35.5
# 17            2048.0                         36.6
# 2              640.0                         29.6
# 5              640.0                         29.5
# 3              640.0                         29.5
# 6              640.0                         29.6
# 44              33.0                         36.6
# 4              640.0                         29.7
# 22             128.0                        103.7
# 31            1369.0                         87.2
# 10               8.0                        114.4
# 27              10.0                         33.8
# 9                8.0                        145.4
# 35             768.0                         46.1
# 39            5000.0                         46.5
#
#     Computational Performance 4  Computational Performance 5
# 30                         -1.0                         -1.0
# 28                         -1.0                         -1.0
# 38                         -1.0                         -1.0
# 43                         22.2                         45.6
# 21                         25.1                         59.6
# 0                          39.7                        133.5
# 32                         46.5                        174.3
# 19                         47.9                        181.1
# 33                         48.2                        181.4
# 14                         53.9                        210.6
# 42                         57.0                        227.1
# 15                         59.5                        239.1
# 41                         61.3                        248.6
# 29                         73.9                        312.4
# 7                          74.3                        308.3
# 12                         74.6                        318.4
# 40                         80.2                        340.7
# 1                          87.4                        375.8
# 34                         89.2                        397.4
# 45                         90.3                        405.8
# 25                         91.6                        396.8
# 23                        131.7                        608.3
# 37                        177.4                        842.1
# 36                        203.3                        963.7
# 26                        204.0                        976.9
# 24                        234.3                       1159.5
# 13                        253.5                       1180.6
# 18                        276.4                       1599.8
# 46                        326.8                       1600.1
# 11                        456.0                         -1.0
# 20                        555.8                       1674.6
# 8                         573.5                         -1.0
# 16                        605.9                         -1.0
# 17                        633.4                         -1.0
# 2                         829.1                         -1.0
# 5                         829.4                         -1.0
# 3                         833.0                         -1.0
# 6                         834.1                         -1.0
# 44                        840.4                         -1.0
# 4                         843.8                         -1.0
# 22                        857.8                         -1.0
# 31                        862.1                         -1.0
# 10                        926.4                         -1.0
# 27                        927.4                         -1.0
# 9                        1135.7                         -1.0
# 35                       1396.6                         -1.0
# 39                       1588.0                         -1.0
